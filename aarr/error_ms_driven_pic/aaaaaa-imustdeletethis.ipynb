# %%
import matplotlib.pyplot as plt
from matplotlib import rc

rc('text', usetex=True)

plt.sunplot(111)

plt.text(0.05, 0.90, r'\underline{Parameters}: ', fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 6
#       2 from matplotlib import rc
#       4 rc('text', usetex=True)
# ----> 6 plt.sunplot(111)
#       8 plt.text(0.05, 0.90, r'\underline{Parameters}: ', fontsize=12)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'sunplot'
